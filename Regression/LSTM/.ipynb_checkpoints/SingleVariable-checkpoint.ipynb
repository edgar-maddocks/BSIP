# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MSFT.csv')
df = df[['Date', 'Close']]
df
# Out:
#            Date       Close
# 0    2022-10-10  229.250000
# 1    2022-10-11  225.410004
# 2    2022-10-12  225.750000
# 3    2022-10-13  234.240005
# 4    2022-10-14  228.559998
# ..          ...         ...
# 246  2023-10-03  313.390015
# 247  2023-10-04  318.959991
# 248  2023-10-05  319.359985
# 249  2023-10-06  327.260010
# 250  2023-10-09  329.820007
#
# [251 rows x 2 columns]

# %%
import datetime
import pandas as pd
df = pd.read_csv("MSFT.csv")
df = df[["Date", "Close"]]
def windowed_dataframe(df, window_size):
    for i in range(window_size + 1):
        shift = window_size - i
        df[f"Target - {shift}"] = df["Close"].shift(shift)
    del df["Close"]
    df = df.iloc[window_size:]
    df = df.reset_index()
    del df["index"]
                
    return df

df = windowed_dataframe(df, 3)
df
# Out:
#            Date  Target - 3  Target - 2  Target - 1  Target - 0
# 0    2022-10-13  229.250000  225.410004  225.750000  234.240005
# 1    2022-10-14  225.410004  225.750000  234.240005  228.559998
# 2    2022-10-17  225.750000  234.240005  228.559998  237.529999
# 3    2022-10-18  234.240005  228.559998  237.529999  238.500000
# 4    2022-10-19  228.559998  237.529999  238.500000  236.479996
# ..          ...         ...         ...         ...         ...
# 243  2023-10-03  313.640015  315.750000  321.799988  313.390015
# 244  2023-10-04  315.750000  321.799988  313.390015  318.959991
# 245  2023-10-05  321.799988  313.390015  318.959991  319.359985
# 246  2023-10-06  313.390015  318.959991  319.359985  327.260010
# 247  2023-10-09  318.959991  319.359985  327.260010  329.820007
#
# [248 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(df)

dates.shape, X.shape, y.shape
# Out:
# ((248,), (248, 3, 1), (248,))

# %%
q_80 = int(len(dates) * 0.8)
q_90 = int(len(dates) * 0.9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)
plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers


model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# %%
def adapt_learning_rate(epoch):
    if epoch <= 100:
        return 0.001
    else:
        return 0.0001

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
my_lr_scheduler = tf.keras.callbacks.LearningRateScheduler(adapt_learning_rate)
cp = ModelCheckpoint("model3/", save_best_only=True)
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=300, callbacks = [cp, my_lr_scheduler])
# Out:
# Epoch 1/300
# 1/7 [===>..........................] - ETA: 9s - loss: 79268.2656 - mean_absolute_error: 279.0391INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 4s 433ms/step - loss: 78931.3750 - mean_absolute_error: 278.1293 - val_loss: 105908.4609 - val_mean_absolute_error: 325.3997 - lr: 0.0010
# Epoch 2/300
# 1/7 [===>..........................] - ETA: 0s - loss: 76191.6562 - mean_absolute_error: 273.1627INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 3s 497ms/step - loss: 78725.0547 - mean_absolute_error: 277.7574 - val_loss: 105707.2500 - val_mean_absolute_error: 325.0903 - lr: 0.0010
# Epoch 3/300
# 1/7 [===>..........................] - ETA: 0s - loss: 72210.7891 - mean_absolute_error: 266.2869INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 380ms/step - loss: 78564.4766 - mean_absolute_error: 277.4693 - val_loss: 105533.5938 - val_mean_absolute_error: 324.8231 - lr: 0.0010
# Epoch 4/300
# 1/7 [===>..........................] - ETA: 0s - loss: 77034.7344 - mean_absolute_error: 275.0524INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 375ms/step - loss: 78415.5781 - mean_absolute_error: 277.1988 - val_loss: 105356.1484 - val_mean_absolute_error: 324.5499 - lr: 0.0010
# Epoch 5/300
# 1/7 [===>..........................] - ETA: 0s - loss: 84957.6875 - mean_absolute_error: 288.7513INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 379ms/step - loss: 78234.1875 - mean_absolute_error: 276.8700 - val_loss: 105058.8906 - val_mean_absolute_error: 324.0916 - lr: 0.0010
# Epoch 6/300
# 1/7 [===>..........................] - ETA: 0s - loss: 81413.5547 - mean_absolute_error: 283.3203INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 379ms/step - loss: 77972.5234 - mean_absolute_error: 276.3971 - val_loss: 104763.4766 - val_mean_absolute_error: 323.6355 - lr: 0.0010
# Epoch 7/300
# 1/7 [===>..........................] - ETA: 0s - loss: 74949.0156 - mean_absolute_error: 271.4707INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 374ms/step - loss: 77698.8047 - mean_absolute_error: 275.9024 - val_loss: 104379.7109 - val_mean_absolute_error: 323.0421 - lr: 0.0010
# Epoch 8/300
# 1/7 [===>..........................] - ETA: 0s - loss: 80099.3438 - mean_absolute_error: 279.7437INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 371ms/step - loss: 77333.0859 - mean_absolute_error: 275.2357 - val_loss: 103848.8203 - val_mean_absolute_error: 322.2193 - lr: 0.0010
# Epoch 9/300
# 1/7 [===>..........................] - ETA: 0s - loss: 74486.4609 - mean_absolute_error: 270.1954INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 372ms/step - loss: 76785.3984 - mean_absolute_error: 274.2436 - val_loss: 103061.2734 - val_mean_absolute_error: 320.9949 - lr: 0.0010
# Epoch 10/300
# 1/7 [===>..........................] - ETA: 0s - loss: 78377.5234 - mean_absolute_error: 277.1486INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 3s 522ms/step - loss: 76003.4609 - mean_absolute_error: 272.8082 - val_loss: 101902.7578 - val_mean_absolute_error: 319.1852 - lr: 0.0010
# Epoch 11/300
# 1/7 [===>..........................] - ETA: 0s - loss: 72763.3516 - mean_absolute_error: 266.8535INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 360ms/step - loss: 74933.3594 - mean_absolute_error: 270.8420 - val_loss: 100554.1016 - val_mean_absolute_error: 317.0656 - lr: 0.0010
# Epoch 12/300
# 1/7 [===>..........................] - ETA: 0s - loss: 73364.8125 - mean_absolute_error: 268.1880INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 370ms/step - loss: 73805.6797 - mean_absolute_error: 268.7579 - val_loss: 99148.2422 - val_mean_absolute_error: 314.8407 - lr: 0.0010
# Epoch 13/300
# 1/7 [===>..........................] - ETA: 0s - loss: 70603.5156 - mean_absolute_error: 263.1880INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 364ms/step - loss: 72486.3516 - mean_absolute_error: 266.2890 - val_loss: 97327.5000 - val_mean_absolute_error: 311.9359 - lr: 0.0010
# Epoch 14/300
# 1/7 [===>..........................] - ETA: 0s - loss: 69615.2344 - mean_absolute_error: 260.4707INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 363ms/step - loss: 70816.2109 - mean_absolute_error: 263.1439 - val_loss: 95101.5234 - val_mean_absolute_error: 308.3471 - lr: 0.0010
# Epoch 15/300
# 1/7 [===>..........................] - ETA: 0s - loss: 72979.0000 - mean_absolute_error: 267.0867INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 366ms/step - loss: 68656.2344 - mean_absolute_error: 258.9920 - val_loss: 92151.6094 - val_mean_absolute_error: 303.5261 - lr: 0.0010
# Epoch 16/300
# 1/7 [===>..........................] - ETA: 0s - loss: 68225.5000 - mean_absolute_error: 257.9874INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 370ms/step - loss: 66141.7578 - mean_absolute_error: 254.0811 - val_loss: 88874.6719 - val_mean_absolute_error: 298.0790 - lr: 0.0010
# Epoch 17/300
# 1/7 [===>..........................] - ETA: 0s - loss: 67965.0312 - mean_absolute_error: 257.4859INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 3s 512ms/step - loss: 63049.0352 - mean_absolute_error: 247.9334 - val_loss: 84648.4297 - val_mean_absolute_error: 290.9035 - lr: 0.0010
# Epoch 18/300
# 1/7 [===>..........................] - ETA: 0s - loss: 56923.1953 - mean_absolute_error: 235.0400INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 364ms/step - loss: 59367.2109 - mean_absolute_error: 240.4072 - val_loss: 80004.1719 - val_mean_absolute_error: 282.8084 - lr: 0.0010
# Epoch 19/300
# 1/7 [===>..........................] - ETA: 0s - loss: 60974.0781 - mean_absolute_error: 243.0386INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 375ms/step - loss: 55369.0508 - mean_absolute_error: 231.9088 - val_loss: 74921.1484 - val_mean_absolute_error: 273.6741 - lr: 0.0010
# Epoch 20/300
# 1/7 [===>..........................] - ETA: 0s - loss: 49409.8242 - mean_absolute_error: 218.8783INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 364ms/step - loss: 50733.5469 - mean_absolute_error: 221.7105 - val_loss: 68882.4375 - val_mean_absolute_error: 262.4098 - lr: 0.0010
# Epoch 21/300
# 1/7 [===>..........................] - ETA: 0s - loss: 49276.7500 - mean_absolute_error: 218.3332INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 366ms/step - loss: 46040.4141 - mean_absolute_error: 210.8293 - val_loss: 63158.9648 - val_mean_absolute_error: 251.2677 - lr: 0.0010
# Epoch 22/300
# 1/7 [===>..........................] - ETA: 0s - loss: 43081.4258 - mean_absolute_error: 203.7605INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 366ms/step - loss: 41293.5039 - mean_absolute_error: 199.2922 - val_loss: 57176.9219 - val_mean_absolute_error: 239.0677 - lr: 0.0010
# Epoch 23/300
# 1/7 [===>..........................] - ETA: 0s - loss: 37873.3477 - mean_absolute_error: 190.5474INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 7/7 [==============================] - 2s 367ms/step - loss: 36337.9102 - mean_absolute_error: 186.4257 - val_loss: 50835.5586 - val_mean_absolute_error: 225.4152 - lr: 0.0010
# Epoch 24/300
# 1/7 [===>..........................] - ETA: 0s - loss: 33296.8008 - mean_absolute_error: 178.6992
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# Cell In[91], line 4
#       2 my_lr_scheduler = tf.keras.callbacks.LearningRateScheduler(adapt_learning_rate)
#       3 cp = ModelCheckpoint("model3/", save_best_only=True)
# ----> 4 model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=300, callbacks = [cp, my_lr_scheduler])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# FailedPreconditionError: {{function_node __wrapped__MergeV2Checkpoints_device_/job:localhost/replica:0/task:0/device:CPU:0}} Failed to rename: model3\variables\variables_temp/part-00000-of-00001.data-00000-of-00001 to: model3\variables\variables.data-00000-of-00001 : The process cannot access the file because it is being used by another process.
# ; Broken pipe [Op:MergeV2Checkpoints]

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy # use model to predict as if no data other than training is known

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
